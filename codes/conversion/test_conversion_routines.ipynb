% %% [markdown]
% Tests for the conversion routine **RstarToR_RN**

% %%
pwd
% Out:
% ans = '/home/sbishoyi_umassd_edu'

% %%
addpath('/home/sbishoyi_umassd_edu/phd_work/projects/aretakis_extremal_hair/codes/conversion/')

q=0.3; m=1;
x=linspace(-100,100,10000);
[Rrsn,Rschm2m] = RstarToR_RN(x,m,q);

% %%
plot(x,Rrsn)
xlim([-120,120])
ylim([-10,100])
Rrsn(1:20)
Rschm2m(1:20)
% Out:
% ans = 1x20 double
%     1.9539    1.9539    1.9539    1.9539    1.9539    1.9539    1.9539    1.9539    1.9539    1.9539    1.9539    1.9539    1.9539    1.9539    1.9539    1.9539    1.9539    1.9539    1.9539    1.9539
% ans = 1x20 double
% 1.0e-17 *
%
%     0.1606    0.1611    0.1616    0.1621    0.1626    0.1631    0.1636    0.1641    0.1646    0.1651    0.1656    0.1661    0.1666    0.1671    0.8893    0.0008    0.0013    0.0002    0.0095    0.0791

% %%
m + sqrt(m^2 - q^2)
% Out:
% ans = 1.9539
