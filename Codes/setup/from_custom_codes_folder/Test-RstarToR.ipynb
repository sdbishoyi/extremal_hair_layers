% %%
clear
rs=linspace(-100,100,100);
m=1;
a=0.9;
rp = m + sqrt(m^2 - a^2)
% Out:
% rp =
%
%     1.4359

% %%
r_new=RstarToRwithSpin_Newton(rs,m,a);
r_old=RstarToRwithSpin(rs,m,a);

% %%
plot(r_new)
% hold on
% plot(r_old-r_new)
xlim([-1 10])

% %%
r_old=RstarToRwithSpin(rs,m,a)
% [r_sch,rsch2m]=RstarToR(rs,m);
r_new=RstarToRwithSpin_Newton(rs,m,a);

% plot(rs,abs(r_old-r_new))
% xlim([-10 10])
% Out:
% r_old =
%
%   Columns 1 through 7
%
%     1.4359    1.4359    1.4359    1.4359    1.4359    1.4359    1.4359
%
%   Columns 8 through 14
%
%     1.4359    1.4359    1.4359    1.4359    1.4359    1.4359    1.4359
%
%   Columns 15 through 21
%
%     1.4359    1.4359    1.4359    1.4359    1.4359    1.4359    1.4359
%
%   Columns 22 through 28
%
%     1.4359    1.4359    1.4359    1.4359    1.4359    1.4359    1.4359
%
%   Columns 29 through 35
%
%     1.4359    1.4359    1.4359    1.4359    1.4359    1.4359    1.4359
%
%   Columns 36 through 42
%
%     1.4359    1.4359    1.4359    1.4359    1.4359    1.4359    1.4359
%
%   Columns 43 through 49
%
%     1.4359    1.4359    1.4359    1.4359    1.4359    1.4359    1.4359
%
%   Columns 50 through 56
%
%     2.1360    2.6691    3.4645    4.5122    5.7641    7.1682    8.6832
%
%   Columns 57 through 63
%
%    10.2798   11.9379   13.6432   15.3857   17.1581   18.9549   20.7719
%
%   Columns 64 through 70
%
% ...

% %%
 
% plot(rs,r_old,'r^')
% hold on
plot(rs,r_new-r_old,'b-')

xlabel("rstar")
ylabel("r")
grid()
% xlim([-10 20])
% ylim([-1e-14 1e-14])

% %%
r_new
% Out:
% r_new =
%
%   Columns 1 through 7
%
%     1.4359    1.4359    1.4359    1.4359    1.4359    1.4359    1.4359
%
%   Columns 8 through 14
%
%     1.4359    1.4359    1.4359    1.4359    1.4359    1.4359    1.4359
%
%   Columns 15 through 21
%
%     1.4359    1.4359    1.4359    1.4359    1.4359    1.4359    1.4359
%
%   Columns 22 through 28
%
%     1.4359    1.4359    1.4359    1.4359    1.4359    1.4359    1.4359
%
%   Columns 29 through 35
%
%     1.4359    1.4359    1.4359    1.4359    1.4359    1.4359    1.4360
%
%   Columns 36 through 42
%
%     1.4360    1.4361    1.4363    1.4367    1.4374    1.4386    1.4410
%
%   Columns 43 through 49
%
%     1.4453    1.4533    1.4680    1.4954    1.5465    1.6416    1.8180
%
%   Columns 50 through 56
%
%     2.1360    2.6691    3.4645    4.5122    5.7641    7.1682    8.6832
%
%   Columns 57 through 63
%
%    10.2798   11.9379   13.6432   15.3857   17.1581   18.9549   20.7719
%
%   Columns 64 through 70
%
% ...

% %%
func= r + (2*m*rp/(rp-rm))*log(abs(r-rp)/2*m) - (2*m*rm/(rp-rm))*log(abs(r-rm)/2*m)
plot(rs,r_sch)
grid()
xlim([-10 20])
ylim([0 5])
% Out:
% Error using eval
% Unrecognized function or variable 'r'.

% %%
r_old;

% %%
plot(rsch,r)
xlabel("rstar")
ylabel("r")
grid()
ylim([1,4])
xlim([-10 10])

% %%
m=1
a=0.5

fprime= 1 + 2*m*rp/((rp-rm)*(r-rp)) - 2*m*rm/((rp-rm)*(r-rm))
% Out:
% Error using eval
% Unrecognized function or variable 'rm'.

% %%
2.6+2*log((2.6/2) - 1)
% Out:
% ans =
%
%     0.1921
